# %% [markdown]
# # 1. Loading the dataset

# %%
import pandas as pd
MH370_df = pd.read_csv("MH370 - Passenger Manifest.csv")
MH370_df.head()
# Out:
#       Name Nationality  Age  Gender          Class Seat No   Ticket  Fare  \
# 0     Yuri         CHN   39  Female  Economy Class     17A  MH-1061   200
# 1    Riley         CHN   45  Female  Economy Class     34G  MH-1212   200
# 2   Camila         CHN   67  Female  Economy Class     38J  MH-1268   200
# 3     Hiro         AUS   31    Male  Economy Class     14H  MH-1406   200
# 4     Zara         CHN   35  Female  Economy Class     22A  MH-1512   200
#
#    Survived
# 0         1
# 1         1
# 2         0
# 3         0
# 4         0

# %% [markdown]
# # 2. Generating the report

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(MH370_df, title="Pandas Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.5&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-03-03 03:15:54.421983&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # 3. Saving the report

# %%
profile.to_file("report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # 4. Exploring the options

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(titanic_df, title = "Pandas Profiling Report", minimal = True)

# %%
profile

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(titanic_df, title = "Pandas Profiling Report", dark_mode = True, lazy = False)
#orange_mode = True

# %%
profile

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(titanic_df, title = "Pandas Profiling Report", sensitive = True, lazy = False)

# %%
profile

# %% [markdown]
# # 6. Comparing the reports

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(MH370_df, train_size = 0.8, stratify = MH370_df["Survived"])
train_df.shape, test_df.shape
# Out:
# ((181, 9), (46, 9))

# %%
from ydata_profiling import ProfileReport, compare
train_report = ProfileReport(train_df, title = "Train")
test_report = ProfileReport(test_df, title = "Test")
comparison_report = compare([train_report, test_report])
# Out:
# ...
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
comparison_report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v[&#x27;v4.6.5&#x27;, &#x27;v4.6.5&#x27;]&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;[datetime.datetime(2024, 3, 3, 3, 18, 22, 422165), datetime.datetime(2024, 3, 3, 3, 18, 23, 379060)]&quot;&gt;&lt;title&gt;Comparing Train and Test&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...
